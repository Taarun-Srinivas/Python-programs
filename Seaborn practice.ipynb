# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
import seaborn as sns 
# %matplotlib inline

# %%
raw_data = sns.load_dataset('tips')
raw_data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x='sex',y='tip',data=raw_data)

# %%
import numpy as np

# %%
sns.barplot(x='sex',y='tip',data=raw_data, estimator = np.std)

# %%
sns.barplot(x='sex',y='tip',data=raw_data, estimator = np.mean)

# %%
sns.countplot(x = 'sex', data = raw_data)

# %%
sns.boxplot(x="day", y="total_bill", data=raw_data,palette='rainbow')

# %%
sns.boxplot(x="sex", y="total_bill", data=raw_data,palette='rainbow')

# %%
sns.boxplot(data=raw_data,palette='rainbow',orient='h')

# %%
sns.boxplot(x="day", y="total_bill", hue="sex",data=raw_data, palette="rainbow")

# %%
sns.violinplot(x="day", y="tip", data=raw_data,palette='rainbow')

# %%
sns.violinplot(x="day", y="total_bill", data=raw_data,hue='smoker',palette='rainbow')

# %%
sns.violinplot(x="day", y="total_bill", data=raw_data,hue='smoker',split=True,palette='Set1')

# %%
sns.stripplot(x="day", y="tip", data=raw_data)

# %%
sns.stripplot(x="day", y="tip", data=raw_data,jitter=True)

# %%
sns.stripplot(x="day", y="tip", data=raw_data,jitter=True,hue='sex',palette='rainbow')

# %%
sns.stripplot(x="day", y="total_bill", data=raw_data,jitter=True,hue='sex',palette='Set1',split=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:2784: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x="sex", y="total_bill",hue = 'sex',data=raw_data)

# %%
sns.swarmplot(x="day", y="tip",hue='sex',data=raw_data, palette="Set1", split=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:2974: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
sns.violinplot(x="tip", y="day", data=raw_data,palette='rainbow')
sns.scatterplot(x="tip", y="day", data=raw_data,color='black',size=3)

# %%
sns.violinplot(x="tip", y="day", data=raw_data,palette='rainbow')
sns.swarmplot(x="tip", y="day", data=raw_data,color='black',size=3)

# %%
sns.factorplot(x='sex',y='tip',data=raw_data,kind='bar')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.distplot(raw_data['tip'])

# %%
sns.distplot(raw_data['tip'],kde=False,bins=40)

# %%
sns.jointplot(x='total_bill',y='tip',data=raw_data,kind='scatter')

# %%
sns.jointplot(x='total_bill',y='size',data=raw_data,kind='hex')

# %%
sns.jointplot(x='total_bill',y='size',data=raw_data,kind='reg')

# %%
sns.pairplot(raw_data)

# %%
sns.pairplot(raw_data,hue='sex',palette='coolwarm')

# %%
sns.rugplot(raw_data['size'])

# %%
sns.rugplot(raw_data['total_bill'])

# %%
# Don't worry about understanding this code!
# It's just for the diagram below
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

dataset = np.random.randn(50)

sns.rugplot(dataset);

x_min = dataset.min() - 2
x_max = dataset.max() + 2


x_axis = np.linspace(x_min,x_max,100)


bandwidth = ((4*dataset.std()**5)/(3*len(dataset)))**.2



kernel_list = []

for data_point in dataset:
    
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    

    kernel = kernel / kernel.max()
    kernel = kernel * .4
    plt.plot(x_axis,kernel,color = 'grey',alpha=0.5)

plt.ylim(0,1)
# Out:
# (0, 1)

# %%
sum_of_kde = np.sum(kernel_list,axis=0)


fig = plt.plot(x_axis,sum_of_kde,color='indianred')

sns.rugplot(dataset,c = 'indianred')

plt.yticks([])

plt.suptitle("Sum of the Basis Functions")
# Out:
# Text(0.5, 0.98, 'Sum of the Basis Functions')

# %%
sns.kdeplot(raw_data['size'])
sns.rugplot(raw_data['size'])

# %%
sns.kdeplot(raw_data['tip'])
sns.rugplot(raw_data['tip'])

# %%
sns.kdeplot(raw_data['total_bill'])
sns.rugplot(raw_data['total_bill'])

# %%
import matplotlib.pyplot as plt

# %%
iris_data = sns.load_dataset('iris')

# %%
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.PairGrid(iris_data)

# %%
iris = iris_data.iloc[:,:4]

# %%
g = sns.PairGrid(iris)
g.map(plt.scatter)

# %%
g = sns.PairGrid(iris)
g.map_diag(plt.hist)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris_data, hue='species', palette='Set1')

# %%
rd = sns.FacetGrid(raw_data, col="time", row="smoker")

# %%
rd1 = sns.FacetGrid(raw_data, col="time",  row="smoker")
rd1 = rd1.map(plt.hist, "total_bill")

# %%
g = sns.FacetGrid(raw_data, col="time",  row="smoker",hue='sex')

g = g.map(plt.scatter, "total_bill", "tip").add_legend()

# %%
g = sns.FacetGrid(iris_data, col="sepal_length",  row="sepal_width",hue='species')
# Notice hwo the arguments come after plt.scatter call
g = g.map(plt.scatter, "sepal_length", "sepal_width").add_legend()

# %%
g = sns.JointGrid(x="sepal_length", y="sepal_width", data=iris_data)

# %%
g1 = sns.JointGrid(x="total_bill", y="tip", data=raw_data)
g1 = g1.plot(sns.regplot, sns.distplot)

# %%
flights = sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights.corr()
# Out:
#                 year  passengers
# year        1.000000    0.921824
# passengers  0.921824    1.000000

# %%
sns.heatmap(flights.corr())

# %%
sns.heatmap(flights.corr(),cmap='coolwarm',annot=True)

# %%
flights.pivot_table(values='passengers',index='month',columns='year')
# Out:
# year       1949  1950  1951  1952  1953  ...  1956  1957  1958  1959  1960
# month                                    ...
# January     112   115   145   171   196  ...   284   315   340   360   417
# February    118   126   150   180   196  ...   277   301   318   342   391
# March       132   141   178   193   236  ...   317   356   362   406   419
# April       129   135   163   181   235  ...   313   348   348   396   461
# May         121   125   172   183   229  ...   318   355   363   420   472
# June        135   149   178   218   243  ...   374   422   435   472   535
# July        148   170   199   230   264  ...   413   465   491   548   622
# August      148   170   199   242   272  ...   405   467   505   559   606
# September   136   158   184   209   237  ...   355   404   404   463   508
# October     119   133   162   191   211  ...   306   347   359   407   461
# November    104   114   146   172   180  ...   271   305   310   362   390
# ...

# %%
a = flights.pivot_table(values='passengers',index='month',columns='year')
sns.heatmap(a)

# %%
sns.heatmap(a,cmap='magma',linecolor='white',linewidths=2)

# %%
sns.clustermap(a)

# %%
sns.clustermap(a,cmap='coolwarm',standard_scale=2)

# %%
sns.lmplot(x='size',y='tip',data=raw_data)

# %%
sns.lmplot(x='size',y='total_bill',data=raw_data)

# %%
sns.lmplot(x='size',y='tip',data=raw_data, hue='sex')

# %%
sns.lmplot(x='tip',y='size',data=raw_data,hue='sex',palette='rainbow')

# %%
sns.lmplot(x='total_bill',y='size',data=raw_data,col='sex')

# %%
sns.lmplot(x="total_bill", y="size", row="sex", col="time",data=raw_data)

# %%
sns.lmplot(x='size',y='tip',data=raw_data,col='day',hue='sex',palette='rainbow')

# %%
sns.lmplot(x='total_bill',y='tip',data=raw_data,col='day',hue='sex',palette='coolwarm',
          aspect=0.6,size=8)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py:574: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.countplot(x='sex',data=raw_data)

# %%
sns.set_style('white')
sns.countplot(x='sex',data=raw_data)

# %%
sns.set_style('ticks')
sns.countplot(x='sex',data=raw_data,palette='deep')

# %%
sns.lmplot(x='total_bill',y='size',size=2,aspect=4,data=raw_data, palette = 'rainbow')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py:574: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #<i> Seaborn Exercise </i>

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
sns.jointplot(x='fare',y='age',data=titanic)

# %%
sns.distplot(titanic['fare'],bins=30,kde=False,color='red')

# %%
sns.boxplot(x='class',y='age',data=titanic,palette='rainbow')

# %%
sns.swarmplot(x='class',y='age',data=titanic,palette='Set2')

# %%
sns.countplot(x='sex',data=titanic)

# %%
sns.heatmap(titanic.corr(),cmap='coolwarm')
plt.title('titanic.corr()')
# Out:
# Text(0.5, 1, 'titanic.corr()')

# %%
g = sns.FacetGrid(data=titanic,col='sex')
g.map(plt.hist,'age')
